# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("ML.csv")

# %%
df.head()
# Out:
#   typeofaction  sourceid  destinationid  amountofmoney                 date  \
# 0      cash-in     30105          28942         494528  2019-07-19 14:40:00
# 1      cash-in     30105           8692         494528  2019-05-17 14:57:00
# 2      cash-in     30105          60094         494528  2019-07-20 13:20:00
# 3      cash-in     30105          20575         494528  2019-07-03 14:15:00
# 4      cash-in     30105          45938         494528  2019-05-26 10:40:00
#
#    isfraud typeoffraud
# 0        1       type1
# 1        1       type1
# 2        1       type1
# 3        1       type1
# 4        1       type1

# %%
#Tipo de dados das respectivas colunas

df.dtypes
# Out:
# typeofaction     object
# sourceid          int64
# destinationid     int64
# amountofmoney     int64
# date             object
# isfraud           int64
# typeoffraud      object
# dtype: object

# %%
#Verificação de valores nulos

df.isna().any()
# Out:
# typeofaction     False
# sourceid         False
# destinationid    False
# amountofmoney    False
# date             False
# isfraud          False
# typeoffraud      False
# dtype: bool

# %%
#(Número de linhas, número de Colunas)

df.shape
# Out:
# (2340, 7)

# %% [markdown]
# <h3> 1.Análise Exploratória dos dados </h3>
# <p>Estes dados estão baseados em 3 processos de lavagem de dinheiro que condizem respectivamente com o tipo de fraude: </p>
# <ol>
# <li> <strong> Money Placement </strong> </li>
# <li> <strong> Money Layering</strong> </li>
# <li> <strong> Money Integration</strong> </li>
# </ol>
#
# <p> Para cada processo, consideramos que: </p>
#     <ol>
#     <li> Processo 1, ocorre a operação de: <strong> Cashing  </strong>  </li>
#     <li> Processo 2 e 3, ocorre a operação de: <strong> Transfer  </strong>  </li>
#     </ol>

# %%
# Tipos de branqueamento de capitais e respectivas quantidades

pie_aml = df.groupby('typeofaction',axis=0)['amountofmoney'].sum()
pie_aml.head()
# Out:
# typeofaction
# cash-in     1107679854
# transfer    4762404112
# Name: amountofmoney, dtype: int64

# %%
pie_aml['amountofmoney'].plot(kind='pie', figsize = (5,6), autopct = '%1.1f%%', startangle = 90, shadow= True )
plt.title('')

# %% [markdown]
# <h3> 2.Tratamento do 1º tipo de Fraude: Money Placement </h3>
# <p> Money placement é uma técnica utilizada em atividades de branqueamento de capitais que consiste em <strong>colocar dinheiro ilícito diretamente em instituições financeiras.</strong> Isso pode ser feito através da abertura de contas bancárias em nome de pessoas físicas ou jurídicas fictícias, ou através do<strong> depósito de grandes quantias de dinheiro em contas já existentes.</strong>

# %%
#Seleção de linhas do DataSET cujo tipo de fraude seja de Money Placement (type1)

fraud_type1= df[df["typeoffraud"]=="type1"]

# %%
fraud_type1.head(25)
# Out:
#    typeofaction  sourceid  destinationid  amountofmoney                 date  \
# 0       cash-in     30105          28942         494528  2019-07-19 14:40:00
# 1       cash-in     30105           8692         494528  2019-05-17 14:57:00
# 2       cash-in     30105          60094         494528  2019-07-20 13:20:00
# 3       cash-in     30105          20575         494528  2019-07-03 14:15:00
# 4       cash-in     30105          45938         494528  2019-05-26 10:40:00
# 5       cash-in     30105          54971         494528  2019-04-06 11:18:00
# 6       cash-in     30105          62257         494528  2019-04-23 08:20:00
# 7       cash-in     30105           1020         494528  2019-07-04 08:59:00
# 8       cash-in     30105          98751         494528  2019-05-06 12:49:00
# 9       cash-in     30105          82016         494528  2019-06-09 12:27:00
# 10      cash-in     30105          13800         494528  2019-04-17 08:18:00
# 11      cash-in     30105          52681         494529  2019-07-18 13:57:00
# 12      cash-in     30105          80113         494529  2019-03-27 13:13:00
# 13      cash-in     30105          64316         494529  2019-06-09 11:43:00
# 14      cash-in     30105          94472         494529  2019-02-21 12:34:00
# 15      cash-in     30105          23762         494529  2019-04-07 12:43:00
# 16      cash-in     30105          12860         494529  2019-04-28 15:08:00
# 17      cash-in     30105          61008         494529  2019-04-19 15:02:00
# 18      cash-in     30105           3164         494529  2019-05-19 09:26:00
# 19      cash-in     30105          24259         494529  2019-04-20 11:48:00
# 20      cash-in     80740          29758         388294  2019-05-03 11:40:00
# 21      cash-in     80740          47869         388294  2019-06-14 08:10:00
# 22      cash-in     80740          79227         388294  2019-03-05 13:22:00
# 23      cash-in     80740          68225         388294  2019-03-03 09:24:00
# 24      cash-in     80740          65031         388294  2019-03-10 12:45:00
#
#     isfraud typeoffraud
# 0         1       type1
# 1         1       type1
# 2         1       type1
# 3         1       type1
# 4         1       type1
# 5         1       type1
# 6         1       type1
# 7         1       type1
# 8         1       type1
# 9         1       type1
# 10        1       type1
# 11        1       type1
# 12        1       type1
# 13        1       type1
# 14        1       type1
# 15        1       type1
# 16        1       type1
# 17        1       type1
# 18        1       type1
# 19        1       type1
# 20        1       type1
# 21        1       type1
# 22        1       type1
# 23        1       type1
# 24        1       type1

# %%
#Agrupamento com base a fonte(sourceid), destino(destinationid), e quantidade de dinheiro(amountofmoney)

df_source_based = fraud_type1.groupby(["sourceid","destinationid"])["amountofmoney"].agg([np.min, np.max, np.sum, np.mean])

# %%
print(df_source_based.head(100))
# Out:
#                           amin    amax     sum      mean
# sourceid destinationid
# 1615     3335           639230  639230  639230  639230.0
#          6054           639230  639230  639230  639230.0
#          6322           639229  639229  639229  639229.0
#          7203           639230  639230  639230  639230.0
#          8552           639230  639230  639230  639230.0
# ...                        ...     ...     ...       ...
# 30105    8692           494528  494528  494528  494528.0
#          12860          494529  494529  494529  494529.0
#          13800          494528  494528  494528  494528.0
#          20575          494528  494528  494528  494528.0
#          23762          494529  494529  494529  494529.0
#
# [100 rows x 4 columns]

# %%
# Verificação dos movimentos da conta nº 30105

_account = fraud_type1[fraud_type1["sourceid"]== 30105]

# %%
grouped_account = _account.groupby(["sourceid","destinationid"])["amountofmoney"].sum()
print(grouped_account)
# Out:
# sourceid  destinationid
# 30105     1020             494528
#           3164             494529
#           8692             494528
#           12860            494529
#           13800            494528
#           20575            494528
#           23762            494529
#           24259            494529
#           28942            494528
#           45938            494528
#           52681            494529
#           54971            494528
#           60094            494528
#           61008            494529
#           62257            494528
#           64316            494529
#           80113            494529
#           82016            494528
#           94472            494529
#           98751            494528
# Name: amountofmoney, dtype: int64

# %% [markdown]
# <p> Aqui podemos verificar que a fonte de nº:<strong> 30105 </strong> efetua vários dépositos com a mesma quantia em várias contas diferentes - Uma característica de Money Placement. </p>

# %% [markdown]
# <h3>3.Tratamento do 2º tipo de Fraude: Money Layering </h3>
# <p>Money layering, ou camadas de dinheiro em português, é uma técnica utilizada em atividades de branqueamento de capitais para dificultar a identificação da origem dos recursos ilícitos. Essa técnica consiste em<strong> movimentar o dinheiro através de várias transações financeiras complexas</strong> e em diferentes jurisdições, a fim de obscurecer a trilha de onde o dinheiro veio. </p>

# %%
fraud_type2= df[df["typeoffraud"]=="type2"]

# %%
fraud_type2.head(20)
# Out:
#     typeofaction  sourceid  destinationid  amountofmoney                 date  \
# 423     transfer     42454          32893        7270189  2019-02-25 11:50:00
# 424     transfer     32893          30530        7270189  2019-03-12 11:43:00
